# %% [markdown]
# ### Plot of Figa

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use(['science','ieee'])

# Load your data from 'data/erasureL1000Mc.txt'
data = np.genfromtxt('data/erasureL1000Nc.txt', names=True, delimiter='\t')

plt.rcParams['grid.color'] = 'gray'  # Grid color
plt.rcParams['grid.linestyle'] = '--'  # Grid line style
plt.rcParams['grid.linewidth'] = 0.5  # Grid line width

plt.rcParams['legend.frameon'] = True  # Show the legend border
#plt.rcParams['legend.edgecolor'] = 'black'  # Border color
#plt.rcParams['legend.linewidth'] = 1.5  # Border line width


# Define the data columns for the plot
L = data['L']
b2 = data['b2']
u2 = data['u2']
b3 = data['b3']
u3 = data['u3']
b4 = data['b4']
u4 = data['u4']

# Create the figure and axis
plt.figure(figsize=(8, 6))
ax = plt.gca()

# Plot the data
ax.semilogy(L, b2, color="#D55E00", linestyle='solid', label=r'$\mathrm{BATS}_L(2,2)$', linewidth=2,
                   marker='o', markersize=8, markevery=80, markerfacecolor='none')
ax.semilogy(L, u2, color="#D55E00", linestyle='--',    label=r'$\mathrm{PEC}^{\mathrm{UB}}_L(2,2)$', linewidth=2,
                   marker='s', markersize=8, markevery=80, markerfacecolor='none')

ax.semilogy(L, b3, color="#E69F00", linestyle='solid', label=r'$\mathrm{BATS}_L(3,3)$', linewidth=2,
                   marker='^', markersize=8, markevery=80, markerfacecolor='none')
ax.semilogy(L, u3, color='#E69F00', linestyle='--',    label=r'$\mathrm{PEC}^{\mathrm{UB}}_L(3,3)$', linewidth=2,
                   marker='*', markersize=8, markevery=80, markerfacecolor='none')

ax.semilogy(L, b4, color='#56B4E9', linestyle='solid', label=r'$\mathrm{BATS}_L(4,4)$', linewidth=2,
                   marker='<', markersize=8, markevery=80, markerfacecolor='none')
ax.semilogy(L, u4, color='#56B4E9', linestyle='--',    label=r'$\mathrm{PEC}^{\mathrm{UB}}_L(4,4)$', linewidth=2,
                   marker='>', markersize=8, markevery=80, markerfacecolor='none')

# Set axis labels and title
ax.set_xlabel('Network Length ($L$)', fontsize=21)
ax.set_ylabel(r'$\mathrm{BATS}_L/\mathrm{PEC}^{\mathrm{UB}}_L$ (bit per use)', fontsize=21)

#ax.set_title('Line Plot with Markers and Legend')

# Set x-axis limits
ax.set_xlim(1, 1000)

# Show legend
ax.legend(loc='best', fontsize=21)

# Show the grid
ax.grid(True, which='both')
ax.tick_params(axis='both', labelsize=21)

ytick_values = [1e4, 1e-1, 1e-6, 1e-11, 1e-16]
ax.set_yticks(ytick_values)

plt.savefig('figa_revision.pdf', bbox_inches='tight')

# %% [markdown]
# ### Plot of Figb

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use(['science','ieee'])

# Load your data from 'data/erasureL1000MNstar.txt'
data = np.genfromtxt('data/erasureL1000MNstar.txt', names=True, delimiter='\t')


plt.rcParams['grid.color'] = 'gray'  # Grid color
plt.rcParams['grid.linestyle'] = '--'  # Grid line style
plt.rcParams['grid.linewidth'] = 0.5  # Grid line width

plt.rcParams['legend.frameon'] = True  # Show the legend border
#plt.rcParams['legend.edgecolor'] = 'black'  # Border color
#plt.rcParams['legend.linewidth'] = 1.5  # Border line width

# Define the data columns for the plot
L = data['L']
b2 = data['b2']
b4 = data['b4']
b8 = data['b8']
b16 = data['b16']
b32 = data['b32']

# Create the figure and axis
plt.figure(figsize=(8, 6))
ax = plt.gca()

# Plot the data
ax.plot(L, b2, color="#D55E00", linestyle='solid', label='$M=2$', linewidth=2,
               marker='o', markersize=8, markevery=80, markerfacecolor='none')

ax.plot(L, b4, color="#E69F00", linestyle='solid', label='$M=4$', linewidth=2,
               marker='s', markersize=8, markevery=80, markerfacecolor='none')

ax.plot(L, b8, color="#56B4E9", linestyle='solid', label='$M=8$', linewidth=2,
               marker='^', markersize=8, markevery=80, markerfacecolor='none')

ax.plot(L, b16, color='#009E73', linestyle='solid', label='$M=16$', linewidth=2,
                marker='*', markersize=8, markevery=80, markerfacecolor='none')

ax.plot(L, b32, color='#CC79A7', linestyle='solid', label='$M=32$', linewidth=2,
                marker='H', markersize=8, markevery=80, markerfacecolor='none')

# Set axis labels and title
ax.set_xlabel('Network Length ($L$)', fontsize=21)
ax.set_ylabel('Optimal Inner Blocklength ($N^*_L$)', fontsize=21)

# Set x-axis limits
ax.set_xlim(1, 1000)

# Show legend
ax.legend(loc='best', fontsize=21)
# Show the grid
ax.grid(True, which='both')
ax.tick_params(axis='both', labelsize=21)

plt.savefig('figb_revision.pdf', bbox_inches='tight')

# %% [markdown]
# ### Plot of Figc

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use(['science','ieee'])

# Load your data from 'data/erasureL1000Mc.txt'
data = np.genfromtxt('data/erasureL1000Mc.txt', names=True, delimiter='\t')

plt.rcParams['grid.color'] = 'gray'  # Grid color
plt.rcParams['grid.linestyle'] = '--'  # Grid line style
plt.rcParams['grid.linewidth'] = 0.5  # Grid line width

plt.rcParams['legend.frameon'] = True  # Show the legend border



# Define the data columns for the plot
L = data['L']
b2 = data['b2']
u2 = data['u2']
b4 = data['b4']
u4 = data['u4']
b8 = data['b8']
u8 = data['u8']
b16 = data['b16']
u16 = data['u16']

# Create the figure and axis
plt.figure(figsize=(8, 6))
ax = plt.gca()

# Plot the data
ax.plot(L, b2, color="#D55E00", linestyle='solid', label='$\\text{BATS}_L(2,N^*_L)$', linewidth=2,
               marker='o', markersize=8, markevery=80, markerfacecolor='none')
ax.plot(L, u2, color="#D55E00", linestyle='--',    label='$\\text{PEC}^{\\text{UB}}_L(2,N^*_L)$', linewidth=2,
               marker='s', markersize=8, markevery=80, markerfacecolor='none')

ax.plot(L, b4, color='#E69F00', linestyle='solid', label='$\\text{BATS}_L(4,N^*_L)$', linewidth=2,
               marker='^', markersize=8, markevery=80, markerfacecolor='none')
ax.plot(L, u4, color='#E69F00', linestyle='dashed', label='$\\text{PEC}^{\\text{UB}}_L(4,N^*_L)$', linewidth=2,
               marker='v', markersize=8, markevery=80, markerfacecolor='none')

ax.plot(L, b8, color='#56B4E9', linestyle='solid', label='$\\text{BATS}_L(8,N^*_L)$', linewidth=2,
               marker='<', markersize=8, markevery=80, markerfacecolor='none')
ax.plot(L, u8, color='#56B4E9', linestyle='dashed', label='$\\text{PEC}^{\\text{UB}}_L(8,N^*_L)$', linewidth=2,
               marker='>', markersize=8, markevery=80, markerfacecolor='none')

ax.plot(L, b16, color='#009E73', linestyle='solid', label='$\\text{BATS}_L(16,N^*_L)$', linewidth=2,
                marker='H', markersize=8, markevery=80, markerfacecolor='none')
ax.plot(L, u16, color='#009E73', linestyle='dashed', label='$\\text{PEC}^{\\text{UB}}_L(16,N^*_L)$', linewidth=2,
                marker='*', markersize=8, markevery=80, markerfacecolor='none')


# Set axis labels and title
ax.set_xlabel('Network Length ($L$)',fontsize=21)
ax.set_ylabel('Rate (bit per use)',fontsize=21)

# Set x-axis limits
ax.set_xlim(1, 1000)
ax.set_ylim(1500, 6000)

# Show legend
#ax.legend(loc='best', fontsize=16)
ax.legend(loc='upper right', bbox_to_anchor=(1.42, 1.02), fontsize=16)



# Show the grid
ax.grid(True, which='both')
ax.tick_params(axis='both', labelsize=21)
plt.savefig('figc_revision.pdf', bbox_inches='tight')
